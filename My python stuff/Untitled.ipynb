# %%
1+1
# Out:
# 2

# %%
print(1+1)
# Out:
# 2

# %%
print(Hello)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 print(Hello)
#
# NameError: name 'Hello' is not defined

# %%
Hello = 1+1
print (Hello)
# Out:
# 2
